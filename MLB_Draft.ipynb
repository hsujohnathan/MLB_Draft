# %%
# WebScrape MLB_Draft
## Pre-processing and cleaning

# %%
import os
import urllib
import webbrowser
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup

# %matplotlib inline

# %%
# The url we will be scraping
url_2016 = "http://www.baseball-reference.com/draft/?overall_pick=1&draft_type=junreg&"

# get the html
html = urllib.request.urlopen(url_2016)

# create the BeautifulSoup object
soup = BeautifulSoup(html, "lxml")

# %%
# Scraping Column headers
# Extract the necessary values for the column headers from the table
# and store them as a list
column_headers = [th.getText() for th in soup.findAll('th', limit=25)]
column_headers = [s for s in column_headers if len(s) != 0]
column_headers = column_headers[1:23]
column_headers
# Out:
# ['Rnd',
#  'DT',
#  'FrRnd',
#  'RdPck',
#  'Tm',
#  'Signed',
#  'Name',
#  'Pos',
#  'WAR',
#  'G',
#  'AB',
#  'HR',
#  'BA',
#  'OPS',
#  'G',
#  'W',
#  'L',
#  'ERA',
#  'WHIP',
#  'SV',
#  'Type',
#  'Drafted Out of']

# %%
len(column_headers)
# Out:
# 22

# %%
# The data is found within the table rows
# We want the elements from the 5th row and on
table_rows = soup.find_all("tr")[1:]
table_rows[5]
# Out:
# <tr class=""><td>2016</td><td align="right"><a href="/draft/index.cgi?year_ID=2016&amp;draft_round=1&amp;draft_type=junreg&amp;query_type=year_round">1</a></td><td align="right"></td><td align="right"><a href="/draft/index.cgi?team_ID=PHI&amp;draft_round=1&amp;draft_type=junreg&amp;query_type=franch_round">FrRnd</a></td><td align="right">1</td><td><a href="/draft/index.cgi?team_ID=PHI&amp;year_ID=2016&amp;draft_type=junreg&amp;query_type=franch_year">Phillies</a></td><td align="center" csk="1">Y</td><td>Mickey Moniak (<a href="/register/player.cgi?id=moniak000mic">minors</a>)</td><td><a href="/draft/index.cgi?pos=OF&amp;year_ID=2016&amp;draft_type=junreg&amp;query_type=pos_year">OF</a></td><td align="right" csk="-1000"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="">HS</td><td><a href="/draft/index.cgi?key_school=0fc7f373&amp;exact=1&amp;query_type=key_school">La Costa Canyon HS (Carlsbad, CA)</a></td></tr>

# %%
def extract_player_data(table_rows):
    """
    Extract and return the the desired information from the td elements within
    the table rows.
    """
    # create the empty list to store the player data
    player_data = []
    
    for row in table_rows:  # for each row do the following

        # Get the text for each table data (td) element in the row
        # Some player names end with ' HOF', if they do, get the text excluding
        # those last 4 characters,
        # otherwise get all the text data from the table data
        player_list = [td.get_text() for td in row.find_all("td")]
        
        
        # there are some empty table rows, which are the repeated 
        # column headers in the table
        # we skip over those rows and and continue the for loop
        if not player_list:
            continue
            
        # Now append the data to list of data
        player_data.append(player_list)
        
    return player_data

# %%
# Create datafram with 2016 draft data

# %%
# extract the data we want
data = extract_player_data(table_rows)
#column_headers
# and then store it in a DataFrame
#df_2016 = pd.DataFrame(data, columns=column_headers)
df_2016  = pd.DataFrame(data)

# %%
data[10]
# Out:
# ['2010',
#  '1',
#  '',
#  'FrRnd',
#  '1',
#  'Nationals',
#  'Y',
#  'Bryce Harper\xa0(minors)',
#  'OF',
#  '21.5',
#  '657',
#  '2336',
#  '121',
#  '.279',
#  '.883',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'JC',
#  'College of Southern Nevada (Henderson, NV)']

# %%
df_2016.columns = ['Year'] + column_headers
df_2016.head()
# Out:
#                                                 Year            Rnd  \
# 0  Type of School Drafted From:(not set for all s...           None
# 1                                                              None
# 2  Name and Came From searches work only for name...           None
# 3  Picks by Position/Round=Pos=\nC\nP\nSS\nOF\n1B...  Player Name:
# 4                                               2016              1
#
#                                                 DT  FrRnd RdPck        Tm  \
# 0                                             None   None  None      None
# 1                                             None   None  None      None
# 2                                             None   None  None      None
# 3  Came From:\n(enter 2-letter code for states)\n    None  None      None
# 4                                                   FrRnd     1  Phillies
#
#   Signed                    Name   Pos   WAR  \
# 0   None                    None  None  None
# 1   None                    None  None  None
# 2   None                    None  None  None
# 3   None                    None  None  None
# 4      Y  Mickey Moniak (minors)    OF
#
#                  ...                    BA   OPS     G     W     L   ERA  \
# 0                ...                  None  None  None  None  None  None
# 1                ...                  None  None  None  None  None  None
# 2                ...                  None  None  None  None  None  None
# 3                ...                  None  None  None  None  None  None
# 4                ...
#
#    WHIP    SV  Type                     Drafted Out of
# 0  None  None  None                               None
# 1  None  None  None                               None
# 2  None  None  None                               None
# 3  None  None  None                               None
# 4                HS  La Costa Canyon HS (Carlsbad, CA)
#
# [5 rows x 23 columns]

# %%
# Scraping all data up to the 1200th pick, creating DataFrame for each pick
draft_dfs_list = []
errors_list = []

# %%
url_template = "http://www.baseball-reference.com/draft/?overall_pick={pick}&draft_type=junreg&"

for pick in range (1, 1201):
    try: 
        url = url_template.format(pick = pick)
        html = urllib.request.urlopen(url)
        soup = BeautifulSoup(html, "lxml") 
        column_headers = [th.getText() for th in soup.findAll('th', limit=23)]
        column_headers = [s for s in column_headers if len(s) != 0]
        column_headers = column_headers[1:]
        
        # select the row for which I want to start collecting data
        table_rows = soup.find_all("tr")[5:]

        # extract the player data from the table rows
        player_data = extract_player_data(table_rows)
        
        pick_df = pd.DataFrame(player_data)
                        
        draft_dfs_list.append(pick_df)
        
    except Exception as e:
        
        error = [url, e]
        errors_list.append(error)

        
print(len((errors_list)))
errors_list
# Out:
# 0
# []

# %%
draft_dfs_list[0:1]
# Out:
# [      0  1  2      3  4             5  6                           7    8   \
#  0   2016  1     FrRnd  1      Phillies  Y      Mickey Moniak (minors)   OF
#  1   2015  1     FrRnd  1  Diamondbacks  Y     Dansby Swanson (minors)   SS
#  2   2014  1     FrRnd  1        Astros  N        Brady Aiken (minors)  LHP
#  3   2013  1     FrRnd  1        Astros  Y         Mark Appel (minors)  RHP
#  4   2012  1     FrRnd  1        Astros  Y      Carlos Correa (minors)   SS
#  5   2011  1     FrRnd  1       Pirates  Y        Gerrit Cole (minors)  RHP
#  6   2010  1     FrRnd  1     Nationals  Y       Bryce Harper (minors)   OF
#  7   2009  1     FrRnd  1     Nationals  Y  Stephen Strasburg (minors)  RHP
#  8   2008  1     FrRnd  1          Rays  Y        Tim Beckham (minors)   SS
#  9   2007  1     FrRnd  1    Devil Rays  Y        David Price (minors)  LHP
#  10  2006  1     FrRnd  1        Royals  Y      Luke Hochevar (minors)  RHP
#  11  2005  1     FrRnd  1  Diamondbacks  Y       Justin Upton (minors)   SS
#  12  2004  1     FrRnd  1        Padres  Y          Matt Bush (minors)   SS
#  13  2003  1     FrRnd  1    Devil Rays  Y       Delmon Young (minors)   OF
#  14  2002  1     FrRnd  1       Pirates  Y   Bryan Bullington (minors)  RHP
#  15  2001  1     FrRnd  1         Twins  Y          Joe Mauer (minors)    C
#  16  2000  1     FrRnd  1       Marlins  Y    Adrian Gonzalez (minors)   1B
#  17  1999  1     FrRnd  1    Devil Rays  Y      Josh Hamilton (minors)   OF
#  18  1998  1     FrRnd  1      Phillies  Y        Pat Burrell (minors)   3B
#  19  1997  1     FrRnd  1        Tigers  Y      Matt Anderson (minors)  RHP
#  20  1996  1     FrRnd  1       Pirates  Y        Kris Benson (minors)  RHP
#  21  1995  1     FrRnd  1        Angels  Y       Darin Erstad (minors)   OF
#  22  1994  1     FrRnd  1          Mets  Y        Paul Wilson (minors)  RHP
#  23  1993  1     FrRnd  1      Mariners  Y     Alex Rodriguez (minors)   SS
#  24  1992  1     FrRnd  1        Astros  Y         Phil Nevin (minors)   3B
#  25  1991  1     FrRnd  1       Yankees  Y       Brien Taylor (minors)  LHP
#  26  1990  1     FrRnd  1        Braves  Y      Chipper Jones (minors)   SS
#  27  1989  1     FrRnd  1       Orioles  Y       Ben McDonald (minors)  RHP
#  28  1988  1     FrRnd  1        Padres  Y         Andy Benes (minors)  RHP
#  29  1987  1     FrRnd  1      Mariners  Y        Ken Griffey (minors)   OF
#  30  1986  1     FrRnd  1       Pirates  Y          Jeff King (minors)   SS
#  31  1985  1     FrRnd  1       Brewers  Y       B.J. Surhoff (minors)   SS
#  32  1984  1     FrRnd  1          Mets  Y        Shawn Abner (minors)   OF
#  33  1983  1     FrRnd  1         Twins  N        Tim Belcher (minors)  RHP
#  34  1982  1     FrRnd  1          Cubs  Y     Shawon Dunston (minors)   SS
#  35  1981  1     FrRnd  1      Mariners  Y         Mike Moore (minors)  RHP
#  36  1980  1     FrRnd  1          Mets  Y  Darryl Strawberry (minors)   OF
#  37  1979  1     FrRnd  1      Mariners  Y        Al Chambers (minors)   OF
#  38  1978  1     FrRnd  1        Braves  Y         Bob Horner (minors)   3B
#  39  1977  1     FrRnd  1     White Sox  Y      Harold Baines (minors)   1B
#  40  1976  1     FrRnd  1        Astros  Y    Floyd Bannister (minors)  LHP
#  41  1975  1     FrRnd  1        Angels  Y      Danny Goodwin (minors)    C
#  42  1974  1     FrRnd  1        Padres  Y         Bill Almon (minors)   SS
#  43  1973  1     FrRnd  1       Rangers  Y        David Clyde (minors)  LHP
#  44  1972  1     FrRnd  1        Padres  Y       Dave Roberts (minors)   3B
#  45  1971  1     FrRnd  1     White Sox  N      Danny Goodwin (minors)    C
#  46  1970  1     FrRnd  1        Padres  Y          Mike Ivie (minors)    C
#  47  1969  1     FrRnd  1      Senators  Y     Jeff Burroughs (minors)   OF
#  48  1968  1     FrRnd  1          Mets  Y           Tim Foli (minors)   SS
#  49  1967  1     FrRnd  1       Yankees  Y       Ron Blomberg (minors)   1B
#  50  1966  1     FrRnd  1          Mets  Y    Steven Chilcott (minors)    C
#  51  1965  1     FrRnd  1     Athletics  Y        Rick Monday (minors)   OF
#
#         9                         ...                            13    14   15  \
#  0                                ...
#  1                                ...                          .302  .803
#  2                                ...
#  3                                ...
#  4    10.1                        ...                          .276  .829
#  5     9.4                        ...                          .178  .421   94
#  6    21.5                        ...                          .279  .883
#  7    18.2                        ...                          .157  .405  156
#  8     1.3                        ...                          .238  .720
#  9    31.9                        ...                          .043  .143  253
#  10    3.1                        ...                          .063  .125  279
#  11   26.7                        ...                          .268  .819
#  12    2.1                        ...                                       58
#  13    2.5                        ...                          .283  .737
#  14   -0.2                        ...                          .333  .667   26
#  15   50.0                        ...                          .308  .837
#  16   43.8                        ...                          .290  .854
#  17   28.1                        ...                          .290  .865
#  18   18.8                        ...                          .253  .834
#  19   -0.5                        ...                                      257
#  20   13.0                        ...                          .131  .337  206
#  21   32.3                        ...                          .282  .743
#  22    2.2                        ...                          .103  .271  170
#  23  117.7                        ...                          .295  .930
#  24   15.8                        ...                          .270  .814
#  25                               ...
#  26   85.0                        ...                          .303  .930
#  27   20.9                        ...                          .000  .000  211
#  28   31.7                        ...                          .143  .390  403
#  29   83.6                        ...                          .284  .907
#  30   16.7                        ...                          .256  .749
#  31   34.3                        ...                          .282  .745
#  32   -1.3                        ...                          .227  .591
#  33   26.2                        ...                          .124  .299  394
#  34   11.5                        ...                          .269  .712
#  35   28.5                        ...                          .000  .000  450
#  36   42.0                        ...                          .259  .862
#  37   -0.5                        ...                          .208  .618
#  38   21.7                        ...                          .277  .839
#  39   38.5                        ...                          .289  .820
#  40   26.9                        ...                          .175  .383  431
#  41   -1.7                        ...                          .236  .674
#  42    4.8                        ...                          .254  .648
#  43    0.7                        ...                                       84
#  44    0.4                        ...                          .239  .644
#  45   -1.7                        ...                          .236  .674
#  46    7.2                        ...                          .269  .744
#  47   17.6                        ...                          .261  .795
#  48    5.5                        ...                          .251  .593
#  49    9.4                        ...                          .293  .832
#  50                               ...
#  51   33.1                        ...                          .264  .804
#
#       16   17    18    19  20   21  \
#  0                              HS
#  1                             4Yr
#  2                              HS
#  3                             4Yr
#  4                              HS
#  5    47   30  3.23  1.20   0  4Yr
#  6                              JC
#  7    69   41  3.17  1.09   0  4Yr
#  8                              HS
#  9   121   65  3.21  1.14   0  4Yr
#  10   46   65  4.98  1.34   3
#  11                             HS
#  12    7    2  2.48  0.94   1   HS
#  13                             HS
#  14    1    9  5.62  1.58   0  4Yr
#  15                             HS
#  16                             HS
#  17                             HS
#  18                            4Yr
#  19   15    7  5.19  1.58  26  4Yr
#  20   70   75  4.42  1.39   0  4Yr
#  21                            4Yr
#  22   40   58  4.86  1.45   0  4Yr
#  23                             HS
#  24                            4Yr
#  25                             HS
#  26                             HS
#  27   78   70  3.91  1.26   0  4Yr
#  28  155  139  3.97  1.31   1  4Yr
#  29                             HS
#  30                            4Yr
#  31                            4Yr
#  32                             HS
#  33  146  140  4.16  1.34   5  4Yr
#  34                             HS
#  35  161  176  4.39  1.42   2  4Yr
#  36                             HS
#  37                             HS
#  38                            4Yr
#  39                             HS
#  40  134  143  4.06  1.33   0  4Yr
#  41                            4Yr
#  42                            4Yr
#  43   18   33  4.63  1.53   0   HS
#  44                            4Yr
#  45                             HS
#  46                             HS
#  47                             HS
#  48                             HS
#  49                             HS
#  50                             HS
#  51                            4Yr
#
#                                                     22
#  0                   La Costa Canyon HS (Carlsbad, CA)
#  1               Vanderbilt University (Nashville, TN)
#  2               Cathedral Catholic HS (San Diego, CA)
#  3                 Stanford University (Palo Alto, CA)
#  4           Puerto Rico Baseball Academy (Gurabo, PR)
#  5   University of California, Los Angeles (Los Ang...
#  6          College of Southern Nevada (Henderson, NV)
#  7          San Diego State University (San Diego, CA)
#  8                            Griffin HS (Griffin, GA)
#  9               Vanderbilt University (Nashville, TN)
#  10
#  11                   Great Bridge HS (Chesapeake, VA)
#  12                     Mission Bay HS (San Diego, CA)
#  13                Adolfo Camarillo HS (Camarillo, CA)
#  14                 Ball State University (Muncie, IN)
#  15                           Cretin HS (St. Paul, MN)
#  16                      Eastlake HS (Chula Vista, CA)
#  17                      Athens Drive HS (Raleigh, NC)
#  18             University of Miami (Coral Gables, FL)
#  19                      Rice University (Houston, TX)
#  20                   Clemson University (Clemson, SC)
#  21    University of Nebraska at Lincoln (Lincoln, NE)
#  22         Florida State University (Tallahassee, FL)
#  23                  Westminster Christian (Miami, FL)
#  24  California State University Fullerton (Fullert...
#  25                    East Carteret HS (Beaufort, NC)
#  26               The Bolles School (Jacksonville, FL)
#  27       Louisiana State University (Baton Rouge, LA)
#  28          University of Evansville (Evansville, IN)
#  29             Archbishop Moeller HS (Cincinnati, OH)
#  30          University of Arkansas (Fayetteville, AR)
#  31  University of North Carolina at Chapel Hill (C...
#  32          Mechanicsburg Area HS (Mechanicsburg, PA)
#  33  Mount Vernon Nazarene University (Mount Vernon...
#  34                 Thomas Jefferson HS (Brooklyn, NY)
#  35                Oral Roberts University (Tulsa, OK)
#  36                      Crenshaw HS (Los Angeles, CA)
#  37                    John Harris HS (Harrisburg, PA)
#  38               Arizona State University (Tempe, AZ)
#  39                      St. Michael's HS (Easton, MD)
#  40               Arizona State University (Tempe, AZ)
#  41  Southern University and A&M College (Baton Rou...
#  42                  Brown University (Providence, RI)
#  43                       Westchester HS (Houston, TX)
#  44                  University of Oregon (Eugene, OR)
#  45                     Peoria Central HS (Peoria, IL)
#  46                            Walker HS (Atlanta, GA)
#  47                 Woodrow Wilson HS (Long Beach, CA)
#  48                   Notre Dame HS (Sherman Oaks, CA)
#  49                       Druid Hills HS (Atlanta, GA)
#  50                 Antelope Valley HS (Lancaster, CA)
#  51               Arizona State University (Tempe, AZ)
#
#  [52 rows x 23 columns]]

# %%
column_headers.insert(0, "Year")
print(column_headers)
# Out:
# ['Year', 'Rnd', 'DT', 'FrRnd', 'RdPck', 'Tm', 'Signed', 'Name', 'Pos', 'WAR', 'G', 'AB', 'HR', 'BA', 'OPS', 'G', 'W', 'L', 'ERA', 'WHIP', 'SV', 'Type', 'Drafted Out of']

# %%
draft_df = pd.concat(draft_dfs_list, axis = 0)

draft_df.columns = column_headers

draft_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0e0398acc744> in <module>()
# ----> 1 draft_df = pd.concat(draft_dfs_list, axis = 0)
#       2
#       3 draft_df.columns = column_headers
#       4
#       5 draft_df.head()
#
# NameError: name 'pd' is not defined

# %%
draft_df.loc[0,:]
# Out:
#     Year Rnd DT  FrRnd RdPck            Tm Signed                       Name  \
# 0   2016   1     FrRnd     1      Phillies      Y     Mickey Moniak (minors)
# 0   2016   1     FrRnd     2          Reds      Y       Nick Senzel (minors)
# 0   2016   1     FrRnd     3        Braves      Y      Ian Anderson (minors)
# 0   2016   1     FrRnd     4       Rockies      Y        Riley Pint (minors)
# 0   2016   1     FrRnd     5       Brewers      Y         Corey Ray (minors)
# 0   2016   1     FrRnd     6     Athletics      Y          A.J. Puk (minors)
# 0   2016   1     FrRnd     7       Marlins      Y   Braxton Garrett (minors)
# 0   2016   1     FrRnd     8        Padres      Y     Cal Quantrill (minors)
# 0   2016   1     FrRnd     9        Tigers      Y      Matt Manning (minors)
# 0   2016   1     FrRnd    10     White Sox      Y      Zack Collins (minors)
# 0   2016   1     FrRnd    11      Mariners      Y        Kyle Lewis (minors)
# 0   2016   1     FrRnd    12       Red Sox      Y      Jason Groome (minors)
# 0   2016   1     FrRnd    13          Rays      Y       Joshua Lowe (minors)
# 0   2016   1     FrRnd    14       Indians      Y       Will Benson (minors)
# 0   2016   1     FrRnd    15         Twins      Y    Alex Kirilloff (minors)
# 0   2016   1     FrRnd    16        Angels      Y       Matt Thaiss (minors)
# 0   2016   1     FrRnd    17        Astros      Y   Forrest Whitley (minors)
# 0   2016   1     FrRnd    18       Yankees      Y  Blake Rutherford (minors)
# 0   2016   1     FrRnd    19          Mets      Y       Justin Dunn (minors)
# 0   2016   1     FrRnd    20       Dodgers      Y         Gavin Lux (minors)
# 0   2016   1     FrRnd    21     Blue Jays      Y          TJ Zeuch (minors)
# 0   2016   1     FrRnd    22       Pirates      Y        Will Craig (minors)
# 0   2016   1     FrRnd    23     Cardinals      Y      Delvin Perez (minors)
# 0   2016   1     FrRnd    24        Padres      Y    Hudson Sanchez (minors)
# 0   2016   1     FrRnd    25        Padres      Y        Eric Lauer (minors)
# 0   2016   1     FrRnd    26     White Sox      Y        Zack Burdi (minors)
# 0   2016   1     FrRnd    27       Orioles      Y      Cody Sedlock (minors)
# 0   2016   1     FrRnd    28     Nationals      Y    Carter Kieboom (minors)
# 0   2016   1     FrRnd    29     Nationals      Y      Dane Dunning (minors)
# 0   2016   1     FrRnd    30       Rangers      Y       Cole Ragans (minors)
# ..   ...  .. ..    ...   ...           ...    ...                        ...
# 0   2016  39     FrRnd    15       Orioles      N       Seth Shuman (minors)
# 0   2016  39     FrRnd    16       Indians      N   Pedro Alfonseca (minors)
# 0   2016  39     FrRnd    17         Twins      Y    Casey Scoggins (minors)
# 0   2016  39     FrRnd    18     Nationals      N    Matthew Mervis (minors)
# 0   2016  39     FrRnd    19        Giants      N   Andrew DiPiazza (minors)
# 0   2016  39     FrRnd    20        Angels      Y   Richard Fecteau (minors)
# 0   2016  39     FrRnd    21        Astros      Y       Tyler Wolfe (minors)
# 0   2016  39     FrRnd    22       Yankees      Y      Brian Keller (minors)
# 0   2016  39     FrRnd    23       Rangers      N       Tyler Walsh (minors)
# 0   2016  39     FrRnd    24          Mets      N       Jordan Hand (minors)
# 0   2016  39     FrRnd    25       Dodgers      N       Ryan Watson (minors)
# 0   2016  39     FrRnd    26     Blue Jays      Y      Chavez Young (minors)
# 0   2016  39     FrRnd    27        Royals      Y  Chase Livingston (minors)
# 0   2016  39     FrRnd    28          Cubs      N     Anthony Block (minors)
# 0   2016  39     FrRnd    29       Pirates      N   Harrison Wenson (minors)
# 0   2016  39     FrRnd    30     Cardinals      N        Aaron Bond (minors)
# 0   2016  40     FrRnd     1      Phillies      N       Trey Morris (minors)
# 0   2016  40     FrRnd     2          Reds      N  Michael Bienlien (minors)
# 0   2016  40     FrRnd     3        Braves      N     Dylan Beasley (minors)
# 0   2016  40     FrRnd     4       Rockies      N      Luca Dalatri (minors)
# 0   2016  40     FrRnd     5       Brewers      N      Kyle Serrano (minors)
# 0   2016  40     FrRnd     6     Athletics      Y    Brett Bittiger (minors)
# 0   2016  40     FrRnd     7       Marlins      N      Evan Douglas (minors)
# 0   2016  40     FrRnd     8        Padres      N      Chris Burica (minors)
# 0   2016  40     FrRnd     9        Tigers      N     Dalton Feeney (minors)
# 0   2016  40     FrRnd    10     White Sox      N    Drew Puglielli (minors)
# 0   2016  40     FrRnd    11      Mariners      N   Adley Rutschman (minors)
# 0   2016  40     FrRnd    12       Red Sox      N      Carter Henry (minors)
# 0   2016  40     FrRnd    13  Diamondbacks      N      Jordan Wiley (minors)
# 0   2016  40     FrRnd    14          Rays      N  Andrew Daschbach (minors)
#
#     Pos WAR                        ...                         BA OPS G  W   \
# 0    OF                            ...
# 0    3B                            ...
# 0   RHP                            ...
# 0   RHP                            ...
# 0    OF                            ...
# 0   LHP                            ...
# 0   LHP                            ...
# 0   RHP                            ...
# 0   RHP                            ...
# 0     C                            ...
# 0    OF                            ...
# 0   LHP                            ...
# 0    3B                            ...
# 0    OF                            ...
# 0    OF                            ...
# 0     C                            ...
# 0   RHP                            ...
# 0    OF                            ...
# 0   RHP                            ...
# 0    SS                            ...
# 0   RHP                            ...
# 0    3B                            ...
# 0    SS                            ...
# 0    SS                            ...
# 0   LHP                            ...
# 0   RHP                            ...
# 0   RHP                            ...
# 0    SS                            ...
# 0   RHP                            ...
# 0   LHP                            ...
# ..  ...  ..                        ...                         ..  .. .. ..
# 0   RHP                            ...
# 0    CF                            ...
# 0    CF                            ...
# 0    1B                            ...
# 0   RHP                            ...
# 0    2B                            ...
# 0    IF                            ...
# 0   RHP                            ...
# 0    SS                            ...
# 0     C                            ...
# 0   RHP                            ...
# 0    CF                            ...
# 0     C                            ...
# 0   LHP                            ...
# 0     C                            ...
# 0    OF                            ...
# 0   RHP                            ...
# 0   RHP                            ...
# 0   RHP                            ...
# 0   RHP                            ...
# 0   RHP                            ...
# 0    2B                            ...
# 0    2B                            ...
# 0   LHP                            ...
# 0   RHP                            ...
# 0    3B                            ...
# 0     C                            ...
# 0   RHP                            ...
# 0    CF                            ...
# 0    1B                            ...
#
#    L  ERA WHIP SV Type                                     Drafted Out of
# 0                   HS                  La Costa Canyon HS (Carlsbad, CA)
# 0                  4Yr            University of Tennessee (Knoxville, TN)
# 0                   HS                Shenendehowa HS (Ballston Lake, NY)
# 0                   HS          St. Thomas Aquinas HS (Overland Park, KS)
# 0                  4Yr          University of Louisville (Louisville, KY)
# 0                  4Yr            University of Florida (Gainesville, FL)
# 0                   HS                         Florence HS (Florence, AL)
# 0                  4Yr                Stanford University (Palo Alto, CA)
# 0                   HS                        Sheldon HS (Sacramento, CA)
# 0                  4Yr             University of Miami (Coral Gables, FL)
# 0                  4Yr                      Mercer University (Macon, GA)
# 0                   HS                         Barnegat HS (Barnegat, NJ)
# 0                   HS                             Pope HS (Marietta, GA)
# 0                   HS                       Westminster HS (Atlanta, GA)
# 0                   HS                           Plum HS (Pittsburgh, PA)
# 0                  4Yr       University of Virginia (Charlottesville, VA)
# 0                   HS                 Alamo Heights HS (San Antonio, TX)
# 0                   HS  Chaminade College Preparatory School (West Hil...
# 0                  4Yr                 Boston College (Chestnut Hill, MA)
# 0                   HS                      Indian Trail HS (Kenosha, WI)
# 0                  4Yr          University of Pittsburgh (Pittsburgh, PA)
# 0                  4Yr         Wake Forest University (Winston-Salem, NC)
# 0                   HS         International Baseball Academy (Ceiba, PR)
# 0                   HS                         Carroll HS (Southlake, TX)
# 0                  4Yr                   Kent State University (Kent, OH)
# 0                  4Yr          University of Louisville (Louisville, KY)
# 0                  4Yr  University of Illinois at Urbana-Champaign (Ch...
# 0                   HS                           Walton HS (Marietta, GA)
# 0                  4Yr            University of Florida (Gainesville, FL)
# 0                   HS       North Florida Christian HS (Tallahassee, FL)
# .. ..  ..  ... ..  ...                                                ...
# 0                   HS                         Valdosta HS (Valdosta, GA)
# 0                   HS             North Kansas City HS (Kansas City, MO)
# 0                  4Yr                    University of Tampa (Tampa, FL)
# 0                   HS               Georgetown Prep (North Bethesda, MD)
# 0                   JC  Mercer County Community College (West Windsor,...
# 0                  4Yr                    Salem State College (Salem, MA)
# 0                  4Yr            Kansas State University (Manhattan, KS)
# 0                  4Yr  University of Wisconsin at Milwaukee (Milwauke...
# 0                  4Yr                 Belmont University (Nashville, TN)
# 0                   JC         College of Southern Nevada (Henderson, NV)
# 0                   HS                             Auburn HS (Auburn, AL)
# 0                   HS     Faith Baptist Christian Academy (Ludowici, GA)
# 0                  4Yr          University of Rhode Island (Kingston, RI)
# 0                   HS                          Newport HS (Bellevue, WA)
# 0                  4Yr             University of Michigan (Ann Arbor, MI)
# 0                   JC    San Jacinto College, North Campus (Houston, TX)
# 0                   HS                      James E. Taylor HS (Katy, TX)
# 0                   HS                   Great Bridge HS (Chesapeake, VA)
# 0                   HS                                 Rome HS (Rome, GA)
# 0                   HS          Christian Brothers Academy (Lincroft, NJ)
# 0                  4Yr            University of Tennessee (Knoxville, TN)
# 0                  4Yr                     Pace University (New York, NY)
# 0                   JC      Spokane Falls Community College (Spokane, WA)
# 0                   HS                    Orange Lutheran HS (Orange, CA)
# 0                   HS                          Century HS (Bismarck, ND)
# 0                   HS                         Gulf Coast HS (Naples, FL)
# 0                   HS                         Sherwood HS (Sherwood, OR)
# 0                   HS            Port Neches-Groves HS (Port Neches, TX)
# 0                   HS             Richland HS (North Richland Hills, TX)
# 0                   HS                   Sacred Heart Prep (Atherton, CA)
#
# [1200 rows x 23 columns]

# %%
# save file
draft_df.to_csv("/Users/hsujohnathan/Google Drive/SOC 401/MLB Draft/data/raw_data/pfr_MLB_draft_data_RAW.csv", index = False)

# %% [markdown]
# # Cleaning the Data
# Now that we have the raw passing data, we need to clean it up a bit in order to do some of the data exploration we want.

# %%
os.getcwd()
# Out:
# '/Users/hsujohnathan/Google Drive/SOC 401/MLB Draft/notebook'

# %%
draft_df_clean = pd.read_csv("../data/raw_data/pfr_MLB_draft_data_RAW.csv", encoding = "ISO-8859-1", low_memory = False)

# %%
draft_df_clean
draft_df_clean.dtypes
# Out:
# Year                int64
# Rnd                object
# DT                float64
# FrRnd              object
# RdPck             float64
# Tm                 object
# Signed             object
# Name               object
# Pos                object
# WAR               float64
# G                 float64
# AB                float64
# HR                float64
# BA                float64
# OPS               float64
# G.1               float64
# W                 float64
# L                 float64
# ERA               float64
# WHIP              float64
# SV                float64
# Type               object
# Drafted Out of     object
# dtype: object

# %%
draft_df_clean.columns
# Out:
# Index(['Year', 'Rnd', 'DT', 'FrRnd', 'RdPck', 'Tm', 'Signed', 'Name', 'Pos',
#        'WAR', 'G', 'AB', 'HR', 'BA', 'OPS', 'G.1', 'W', 'L', 'ERA', 'WHIP',
#        'SV', 'Type', 'Drafted Out of'],
#       dtype='object')

# %%
draft_df_clean["Drafted Out of"] = draft_df_clean["Drafted Out of"].astype(str)
draft_df_clean["State"] = draft_df_clean["Drafted Out of"].apply(lambda x: x[-3:].replace(")", ""))
draft_df_clean["State"].unique()
# Out:
# array(['AZ', 'CA', 'TX', 'FL', 'NV', 'OH', 'MO', 'MD', 'PA', 'MA', 'CT',
#        'MN', 'OK', 'VA', 'AL', 'IL', 'MI', 'MS', 'PR', 'IN', 'NY', 'GA',
#        'WA', 'NJ', 'CO', 'TN', 'LA', 'AR', 'SC', 'ON', 'OR', 'UT', 'KS',
#        'KY', 'IA', 'QC', 'nan', 'NH', 'NC', 'HI', 'NE', 'ND', 'WI', 'BC',
#        'MB', 'DE', 'WV', 'ME', 'ID', 'SD', 'VT', 'NM', 'RI', 'WY', 'DC',
#        'AB', 'MT', 'NS', 'AK', 'SK', '(FL', 'VI', 'NL', 'NB'], dtype=object)

# %%
draft_columns = {'Year':'Year', 'Rnd':'Round','DT':'DT', 'FrRnd':'FrRnd', 'RdPck':'Round Pick',
                 'Tm':'Team', 'Signed':'Signed', 'Name':'Name', 'Pos':'Position',
                 'WAR':'WAR', 'G':'Games Played',
                 'AB': 'At bat', 'HR':'Homerun', 'BA':'BA',
                 'OPS': 'OPS', 'G.1':'Games Pitched', 'W': 'Wins',
                 'L':'Losses', 'ERA':'ERA', 'WHIP':'WHIP', 'SV':'Saves',
                 'Type': 'Draft Type', 'Drafted Out of': 'Drafted Out of'
                }
ordered_columns =  ['Year', 'Round',
                 'Team', 'Signed', 'Name', 'Position',
                 'WAR', 'Games Played',
                 'At bat', 'Homerun', 'BA',
                 'OPS', 'Wins',
                 'Losses', 'ERA', 'WHIP',
                 'Saves', 'Draft Type', 'State'
                ]

# %%
draft_df_clean.rename(index=str, columns = draft_columns, inplace = True)
draft_df_clean
# Out:
#        Year Round             Team Signed                           Name  \
# 291    1985     1          Pirates      Y          Barry BondsåÊ(minors)
# 2014   1982     2           Giants      N          Barry BondsåÊ(minors)
# 15025  1981    12             Mets      N        Roger ClemensåÊ(minors)
# 969    1983     1          Red Sox      Y        Roger ClemensåÊ(minors)
# 23     1993     1         Mariners      Y       Alex RodriguezåÊ(minors)
# 4987   1976     4        Athletics      Y     Rickey HendersonåÊ(minors)
# 10047  1965    10          Dodgers      N           Tom SeaveråÊ(minors)
# 1595   1984     2             Cubs      Y          Greg MadduxåÊ(minors)
# 1556   1971     2         Phillies      Y         Mike SchmidtåÊ(minors)
# 4616   1982     4           Braves      N        Randy JohnsonåÊ(minors)
# 1855   1985     2            Expos      Y        Randy JohnsonåÊ(minors)
# 20889  1999    13        Cardinals      Y        Albert PujolsåÊ(minors)
# 2489   1978     2          Orioles      Y           Cal RipkenåÊ(minors)
# 2860   1969     3            Twins      Y        Bert BlylevenåÊ(minors)
# 8629   1976     7          Red Sox      Y           Wade BoggsåÊ(minors)
# 1504   1971     2           Royals      Y         George BrettåÊ(minors)
# 26     1990     1           Braves      Y        Chipper JonesåÊ(minors)
# 29     1987     1         Mariners      Y          Ken GriffeyåÊ(minors)
# 14187  1987    11          Orioles      N         Mike MussinaåÊ(minors)
# 1015   1990     1          Orioles      Y         Mike MussinaåÊ(minors)
# 15354  1965    12             Mets      Y           Nolan RyanåÊ(minors)
# 2431   1984     2           Braves      Y          Tom GlavineåÊ(minors)
# 5700   1989     4          Red Sox      Y         Jeff BagwellåÊ(minors)
# 147    1973     1          Brewers      Y          Robin YountåÊ(minors)
# 7588   1976     7           Tigers      N          Ozzie SmithåÊ(minors)
# 4465   1977     4           Padres      Y          Ozzie SmithåÊ(minors)
# 143    1977     1          Brewers      Y         Paul MolitoråÊ(minors)
# 30538  1974    28        Cardinals      N         Paul MolitoråÊ(minors)
# 1875   1965     2             Reds      Y         Johnny BenchåÊ(minors)
# 5144   1975     5           Tigers      Y         Lou WhitakeråÊ(minors)
# ...     ...   ...              ...    ...                            ...
# 20544  1980    16         Mariners      Y           John MosesåÊ(minors)
# 1718   1966     2             Reds      Y        Darrel ChaneyåÊ(minors)
# 4889   1970     4           Braves      Y       Rowland OfficeåÊ(minors)
# 1766   1970     2           Angels      Y           Dan BriggsåÊ(minors)
# 379    2001     1          Pirates      Y  John Van BenschotenåÊ(minors)
# 489    1995     1          Pirates      Y       Chad HermansenåÊ(minors)
# 9702   1996     7            Twins      Y         Chad MoelleråÊ(minors)
# 36423  1993    25          Yankees      N         Chad MoelleråÊ(minors)
# 3331   1966     4          Red Sox      N           Skip JutzeåÊ(minors)
# 1158   2003     1           Angels      Y         Brandon WoodåÊ(minors)
# 16777  1999    10           Astros      N           Greg DobbsåÊ(minors)
# 565    1971     1           Tigers      Y          Tom VeryzeråÊ(minors)
# 2201   2003     2  Braves via Cubs      Y         *Jo-Jo ReyesåÊ(minors)
# 31692  1966    32             Mets      N        Kurt BevacquaåÊ(minors)
# 36973  1992    25          Marlins      Y          Andy LarkinåÊ(minors)
# 6327   1987     5            Expos      Y     Archi CianfroccoåÊ(minors)
# 29169  1991    21             Reds      Y         Kevin JarvisåÊ(minors)
# 1589   1990    1s           Astros      Y      *Brian WilliamsåÊ(minors)
# 14635  2007     9          Rockies      Y       Jordan PachecoåÊ(minors)
# 3102   1987     3          Pirates      N       Brian WilliamsåÊ(minors)
# 22223  1965    21        Cardinals      N           Dan McGinnåÊ(minors)
# 8059   1973     7            Twins      Y           Luis GomezåÊ(minors)
# 4038   1987     3         Phillies      Y          Kim BatisteåÊ(minors)
# 21674  1994    15           Tigers      Y          Daryle WardåÊ(minors)
# 303    1973     1           Giants      Y     Johnnie LeMasteråÊ(minors)
# 354    1974     1             Cubs      Y        Scot ThompsonåÊ(minors)
# 511    1973     1           Braves      Y          Pat RockettåÊ(minors)
# 569    1967     1          Indians      Y       Jack HeidemannåÊ(minors)
# 30179  1969    25             Mets      N           Vic HarrisåÊ(minors)
# 4783   1972     4           Tigers      Y            Dan MeyeråÊ(minors)
#
#       Position    WAR  Games Played   At bat  Homerun     BA    OPS   Wins  \
# 291         OF  162.4        2986.0   9847.0    762.0  0.298  1.051    0.0
# 2014        OF  162.4        2986.0   9847.0    762.0  0.298  1.051    0.0
# 15025      RHP  140.3         709.0    179.0      0.0  0.173  0.443  354.0
# 969        RHP  140.3         709.0    179.0      0.0  0.173  0.443  354.0
# 23          SS  117.7        2784.0  10566.0    696.0  0.295  0.930    0.0
# 4987        OF  110.8        3081.0  10961.0    297.0  0.279  0.820    0.0
# 10047      RHP  110.5         677.0   1315.0     12.0  0.154  0.429  311.0
# 1595       RHP  106.9         759.0   1591.0      5.0  0.171  0.395  355.0
# 1556        SS  106.5        2404.0   8352.0    548.0  0.267  0.908    0.0
# 4616       LHP  102.1         619.0    625.0      1.0  0.125  0.305  303.0
# 1855       LHP  102.1         619.0    625.0      1.0  0.125  0.305  303.0
# 20889       3B  101.1        2426.0   9138.0    591.0  0.309  0.965    0.0
# 2489        3B   95.5        3001.0  11551.0    431.0  0.276  0.788    0.0
# 2860       RHP   95.3         699.0    451.0      0.0  0.131  0.290  287.0
# 8629        SS   91.1        2440.0   9180.0    118.0  0.328  0.858    0.0
# 1504        SS   88.4        2707.0  10349.0    317.0  0.305  0.857    0.0
# 26          SS   85.0        2499.0   8984.0    468.0  0.303  0.930    0.0
# 29          OF   83.6        2671.0   9801.0    630.0  0.284  0.907    0.0
# 14187      RHP   83.0         537.0     52.0      0.0  0.173  0.381  270.0
# 1015       RHP   83.0         537.0     52.0      0.0  0.173  0.381  270.0
# 15354      RHP   81.8         807.0    852.0      2.0  0.110  0.282  324.0
# 2431       LHP   81.4         709.0   1323.0      1.0  0.186  0.454  305.0
# 5700        3B   79.6        2150.0   7797.0    449.0  0.297  0.948    0.0
# 147         SS   77.0        2856.0  11008.0    251.0  0.285  0.772    0.0
# 7588        SS   76.5        2573.0   9396.0     28.0  0.262  0.666    0.0
# 4465        SS   76.5        2573.0   9396.0     28.0  0.262  0.666    0.0
# 143         SS   75.4        2683.0  10835.0    234.0  0.306  0.817    0.0
# 30538       SS   75.4        2683.0  10835.0    234.0  0.306  0.817    0.0
# 1875         C   75.0        2158.0   7658.0    389.0  0.267  0.817    0.0
# 5144        3B   74.9        2390.0   8570.0    244.0  0.276  0.789    0.0
# ...        ...    ...           ...      ...      ...    ...    ...    ...
# 20544       OF   -3.3         769.0   1723.0     11.0  0.254  0.646    0.0
# 1718        SS   -3.3         915.0   2113.0     14.0  0.217  0.584    0.0
# 4889        OF   -3.4         899.0   2413.0     32.0  0.259  0.665    0.0
# 1766       LHP   -3.5         325.0    688.0     12.0  0.195  0.543    0.0
# 379        RHP   -3.5          26.0     21.0      1.0  0.095  0.494    2.0
# 489         SS   -3.6         189.0    492.0     13.0  0.195  0.584    0.0
# 9702         C   -3.6         501.0   1392.0     29.0  0.226  0.640    0.0
# 36423        C   -3.6         501.0   1392.0     29.0  0.226  0.640    0.0
# 3331         C   -3.7         254.0    656.0      3.0  0.215  0.512    0.0
# 1158        SS   -3.7         272.0    700.0     18.0  0.186  0.513    0.0
# 16777       3B   -3.7         959.0   2097.0     46.0  0.261  0.692    0.0
# 565         SS   -3.7         996.0   2848.0     14.0  0.241  0.577    0.0
# 2201       LHP   -3.8          77.0     63.0      0.0  0.143  0.369   13.0
# 31692       2B   -3.8         970.0   2117.0     27.0  0.236  0.632    0.0
# 36973      RHP   -3.9          39.0     32.0      0.0  0.125  0.277    3.0
# 6327        SS   -3.9         500.0   1276.0     34.0  0.241  0.670    0.0
# 29169      RHP   -3.9         191.0    188.0      1.0  0.160  0.431   34.0
# 1589       RHP   -4.0         260.0     85.0      0.0  0.176  0.398   26.0
# 14635       2B   -4.0         377.0   1076.0     10.0  0.272  0.675    0.0
# 3102        SS   -4.0         260.0     85.0      0.0  0.176  0.398   26.0
# 22223      LHP   -4.1         211.0     91.0      1.0  0.165  0.385   15.0
# 8059        SS   -4.2         609.0   1251.0      0.0  0.210  0.500    0.0
# 4038        SS   -4.4         251.0    658.0     10.0  0.234  0.567    0.0
# 21674       1B   -4.4         948.0   2234.0     90.0  0.263  0.768    0.0
# 303         SS   -5.4        1039.0   3191.0     22.0  0.222  0.566    0.0
# 354         OF   -5.5         626.0   1273.0      5.0  0.262  0.640    0.0
# 511         2B   -5.5         152.0    411.0      1.0  0.214  0.539    0.0
# 569         SS   -6.1         426.0   1093.0      9.0  0.211  0.532    0.0
# 30179       SS   -6.2         579.0   1610.0     13.0  0.217  0.582    0.0
# 4783        2B   -6.5        1118.0   3734.0     86.0  0.253  0.673    0.0
#
#        Losses    ERA  WHIP  Saves Draft Type  \
# 291       0.0   0.00  0.00    0.0        4Yr
# 2014      0.0   0.00  0.00    0.0         HS
# 15025   184.0   3.12  1.17    0.0         JC
# 969     184.0   3.12  1.17    0.0        4Yr
# 23        0.0   0.00  0.00    0.0         HS
# 4987      0.0   0.00  0.00    0.0         HS
# 10047   205.0   2.86  1.12    1.0        4Yr
# 1595    227.0   3.16  1.14    0.0         HS
# 1556      0.0   0.00  0.00    0.0        4Yr
# 4616    166.0   3.29  1.17    2.0         HS
# 1855    166.0   3.29  1.17    2.0        4Yr
# 20889     0.0   0.00  0.00    0.0         JC
# 2489      0.0   0.00  0.00    0.0         HS
# 2860    250.0   3.31  1.20    0.0         HS
# 8629      0.0   3.86  1.71    0.0         HS
# 1504      0.0   0.00  0.00    0.0         HS
# 26        0.0   0.00  0.00    0.0         HS
# 29        0.0   0.00  0.00    0.0         HS
# 14187   153.0   3.68  1.19    0.0         HS
# 1015    153.0   3.68  1.19    0.0        4Yr
# 15354   292.0   3.19  1.25    3.0         HS
# 2431    203.0   3.54  1.31    0.0         HS
# 5700      0.0   0.00  0.00    0.0        4Yr
# 147       0.0   0.00  0.00    0.0         HS
# 7588      0.0   0.00  0.00    0.0        4Yr
# 4465      0.0   0.00  0.00    0.0        4Yr
# 143       0.0   0.00  0.00    0.0        4Yr
# 30538     0.0   0.00  0.00    0.0         HS
# 1875      0.0   0.00  0.00    0.0         HS
# 5144      0.0   0.00  0.00    0.0         HS
# ...       ...    ...   ...    ...        ...
# 20544     0.0   9.00  2.67    0.0        4Yr
# 1718      0.0   0.00  0.00    0.0         HS
# 4889      0.0   0.00  0.00    0.0         HS
# 1766      0.0   0.00  0.00    0.0         HS
# 379      13.0   9.20  2.14    0.0        4Yr
# 489       0.0   0.00  0.00    0.0         HS
# 9702      0.0   0.00  0.00    0.0        4Yr
# 36423     0.0   0.00  0.00    0.0         HS
# 3331      0.0   0.00  0.00    0.0        4Yr
# 1158      0.0   0.00  0.00    0.0         HS
# 16777     0.0   0.00  0.00    0.0        4Yr
# 565       0.0   0.00  0.00    0.0         HS
# 2201     26.0   6.06  1.64    0.0         HS
# 31692     0.0   0.00  0.00    0.0         JC
# 36973    11.0   8.86  2.03    1.0         HS
# 6327      0.0   0.00  0.00    0.0        4Yr
# 29169    49.0   6.03  1.54    1.0        4Yr
# 1589     38.0   5.37  1.66    6.0        4Yr
# 14635     0.0   0.00  0.00    0.0        4Yr
# 3102     38.0   5.37  1.66    6.0         HS
# 22223    30.0   5.11  1.63   10.0        4Yr
# 8059      0.0  27.00  5.00    0.0        4Yr
# 4038      0.0   0.00  0.00    0.0         HS
# 21674     0.0   0.00  0.00    0.0         JC
# 303       0.0   0.00  0.00    0.0         HS
# 354       0.0   0.00  0.00    0.0         HS
# 511       0.0   0.00  0.00    0.0         HS
# 569       0.0   0.00  0.00    0.0         HS
# 30179     0.0   0.00  0.00    0.0         JC
# 4783      0.0   0.00  0.00    0.0         JC
#
#                                           Drafted Out of State
# 291                 Arizona State University (Tempe, AZ)    AZ
# 2014                            Serra HS (San Mateo, CA)    CA
# 15025                 San Jacinto College (Pasadena, TX)    TX
# 969           University of Texas at Austin (Austin, TX)    TX
# 23                     Westminster Christian (Miami, FL)    FL
# 4987                          Technical HS (Oakland, CA)    CA
# 10047  University of Southern California (Los Angeles...    CA
# 1595                           Valley HS (Las Vegas, NV)    NV
# 1556                        Ohio University (Athens, OH)    OH
# 4616                        Livermore HS (Livermore, CA)    CA
# 1855   University of Southern California (Los Angeles...    CA
# 20889    Maple Woods Community College (Kansas City, MO)    MO
# 2489                          Aberdeen HS (Aberdeen, MD)    MD
# 2860                      Santiago HS (Garden Grove, CA)    CA
# 8629                          H. B. Plant HS (Tampa, FL)    FL
# 1504                      El Segundo HS (El Segundo, CA)    CA
# 26                  The Bolles School (Jacksonville, FL)    FL
# 29                Archbishop Moeller HS (Cincinnati, OH)    OH
# 14187               Montoursville HS (Montoursville, PA)    PA
# 1015                 Stanford University (Palo Alto, CA)    CA
# 15354                               Alvin HS (Alvin, TX)    TX
# 2431                        Billerica HS (Billerica, MA)    MA
# 5700          University of Hartford (West Hartford, CT)    CT
# 147                         Taft HS (Woodland Hills, CA)    CA
# 7588   California Polytechnic State University, San L...    CA
# 4465   California Polytechnic State University, San L...    CA
# 143            University of Minnesota (Minneapolis, MN)    MN
# 30538                           Cretin HS (St. Paul, MN)    MN
# 1875                              Binger HS (Binger, OK)    OK
# 5144                  Martinsville HS (Martinsville, VA)    VA
# ...                                                  ...   ...
# 20544                 University of Arizona (Tucson, AZ)    AZ
# 1718                             Morton HS (Hammond, IN)    IN
# 4889                       McClatchy HS (Sacramento, CA)    CA
# 1766                              Sonoma HS (Sonoma, CA)    CA
# 379                     Kent State University (Kent, OH)    OH
# 489                      Green Valley HS (Henderson, NV)    NV
# 9702   University of Southern California (Los Angeles...    CA
# 36423                             Upland HS (Upland, CA)    CA
# 3331   Central Connecticut State University (New Brit...    CT
# 1158                         Horizon HS (Scottsdale, AZ)    AZ
# 16777  California State University Long Beach (Long B...    CA
# 565                                 Islip HS (Islip, NY)    NY
# 2201                   Riverside Poly HS (Riverside, CA)    CA
# 31692                     Miami-Dade College (Miami, FL)    FL
# 36973                             South HS (Medford, OR)    OR
# 6327              Purdue University (West Lafayette, IN)    IN
# 29169         Wake Forest University (Winston-Salem, NC)    NC
# 1589         University of South Carolina (Columbia, SC)    SC
# 14635         University of New Mexico (Albuquerque, NM)    NM
# 3102                        Lewisville HS (Richburg, SC)    SC
# 22223          University of Notre Dame (South Bend, IN)    IN
# 8059   University of California, Los Angeles (Los Ang...    CA
# 4038                        St. Amant HS (St. Amant, LA)    LA
# 21674            Rancho Santiago College (Santa Ana, CA)    CA
# 303                     Paintsville HS (Paintsville, KY)    KY
# 354                             Knoch HS (Saxonburg, PA)    PA
# 511                   Robert E. Lee HS (San Antonio, TX)    TX
# 569                             Brenham HS (Brenham, TX)    TX
# 30179       Los Angeles Valley College (Los Angeles, CA)    CA
# 4783                   Santa Ana College (Santa Ana, CA)    CA
#
# [54308 rows x 20 columns]

# %%
draft_df_clean.head(10)
# Out:
#        Year Round       Team Signed                        Name Position  \
# 291    1985     1    Pirates      Y       Barry BondsåÊ(minors)       OF
# 2014   1982     2     Giants      N       Barry BondsåÊ(minors)       OF
# 15025  1981    12       Mets      N     Roger ClemensåÊ(minors)      RHP
# 969    1983     1    Red Sox      Y     Roger ClemensåÊ(minors)      RHP
# 23     1993     1   Mariners      Y    Alex RodriguezåÊ(minors)       SS
# 4987   1976     4  Athletics      Y  Rickey HendersonåÊ(minors)       OF
# 10047  1965    10    Dodgers      N        Tom SeaveråÊ(minors)      RHP
# 1595   1984     2       Cubs      Y       Greg MadduxåÊ(minors)      RHP
# 1556   1971     2   Phillies      Y      Mike SchmidtåÊ(minors)       SS
# 4616   1982     4     Braves      N     Randy JohnsonåÊ(minors)      LHP
#
#          WAR  Games Played   At bat  Homerun     BA    OPS   Wins  Losses  \
# 291    162.4        2986.0   9847.0    762.0  0.298  1.051    0.0     0.0
# 2014   162.4        2986.0   9847.0    762.0  0.298  1.051    0.0     0.0
# 15025  140.3         709.0    179.0      0.0  0.173  0.443  354.0   184.0
# 969    140.3         709.0    179.0      0.0  0.173  0.443  354.0   184.0
# 23     117.7        2784.0  10566.0    696.0  0.295  0.930    0.0     0.0
# 4987   110.8        3081.0  10961.0    297.0  0.279  0.820    0.0     0.0
# 10047  110.5         677.0   1315.0     12.0  0.154  0.429  311.0   205.0
# 1595   106.9         759.0   1591.0      5.0  0.171  0.395  355.0   227.0
# 1556   106.5        2404.0   8352.0    548.0  0.267  0.908    0.0     0.0
# 4616   102.1         619.0    625.0      1.0  0.125  0.305  303.0   166.0
#
#         ERA  WHIP  Saves Draft Type  \
# 291    0.00  0.00    0.0        4Yr
# 2014   0.00  0.00    0.0         HS
# 15025  3.12  1.17    0.0         JC
# 969    3.12  1.17    0.0        4Yr
# 23     0.00  0.00    0.0         HS
# 4987   0.00  0.00    0.0         HS
# 10047  2.86  1.12    1.0        4Yr
# 1595   3.16  1.14    0.0         HS
# 1556   0.00  0.00    0.0        4Yr
# 4616   3.29  1.17    2.0         HS
#
#                                           Drafted Out of State
# 291                 Arizona State University (Tempe, AZ)    AZ
# 2014                            Serra HS (San Mateo, CA)    CA
# 15025                 San Jacinto College (Pasadena, TX)    TX
# 969           University of Texas at Austin (Austin, TX)    TX
# 23                     Westminster Christian (Miami, FL)    FL
# 4987                          Technical HS (Oakland, CA)    CA
# 10047  University of Southern California (Los Angeles...    CA
# 1595                           Valley HS (Las Vegas, NV)    NV
# 1556                        Ohio University (Athens, OH)    OH
# 4616                        Livermore HS (Livermore, CA)    CA

# %%
draft_df_clean = pd.DataFrame(data = draft_df_clean, columns = ordered_columns)
draft_df_clean = draft_df_clean.apply(pd.to_numeric, errors="ignore")

# %%
num_cols = draft_df_clean.columns[draft_df_clean.dtypes != object]
draft_df_clean.loc[:, num_cols] = draft_df_clean.loc[:, num_cols].fillna(0)

# %%
draft_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54308 entries, 291 to 4783
# Data columns (total 19 columns):
# Year            54308 non-null int64
# Round           54308 non-null object
# Team            54308 non-null object
# Signed          54308 non-null object
# Name            54308 non-null object
# Position        54301 non-null object
# WAR             54308 non-null float64
# Games Played    54308 non-null float64
# At bat          54308 non-null float64
# Homerun         54308 non-null float64
# BA              54308 non-null float64
# OPS             54308 non-null float64
# Wins            54308 non-null float64
# Losses          54308 non-null float64
# ERA             54308 non-null float64
# WHIP            54308 non-null float64
# Saves           54308 non-null float64
# Draft Type      53822 non-null object
# State           54308 non-null object
# dtypes: float64(11), int64(1), object(7)
# memory usage: 8.3+ MB

# %%
draft_df_clean = draft_df_clean[pd.notnull(draft_df_clean['Name'])]
draft_df_clean.sort_values('WAR', ascending=False, axis=0, inplace=True)

# %%
draft_df_clean.to_csv("/Users/hsujohnathan/Google Drive/SOC 401/MLB Draft/data/clean_data/pfr_MLB_draft_data_clean_python.csv", index=False)
draft_df_clean.head(10)
# Out:
#        Year Round       Team Signed                        Name Position  \
# 291    1985     1    Pirates      Y       Barry BondsåÊ(minors)       OF
# 2014   1982     2     Giants      N       Barry BondsåÊ(minors)       OF
# 15025  1981    12       Mets      N     Roger ClemensåÊ(minors)      RHP
# 969    1983     1    Red Sox      Y     Roger ClemensåÊ(minors)      RHP
# 23     1993     1   Mariners      Y    Alex RodriguezåÊ(minors)       SS
# 4987   1976     4  Athletics      Y  Rickey HendersonåÊ(minors)       OF
# 10047  1965    10    Dodgers      N        Tom SeaveråÊ(minors)      RHP
# 1595   1984     2       Cubs      Y       Greg MadduxåÊ(minors)      RHP
# 1556   1971     2   Phillies      Y      Mike SchmidtåÊ(minors)       SS
# 4616   1982     4     Braves      N     Randy JohnsonåÊ(minors)      LHP
#
#          WAR  Games Played   At bat  Homerun     BA    OPS   Wins  Losses  \
# 291    162.4        2986.0   9847.0    762.0  0.298  1.051    0.0     0.0
# 2014   162.4        2986.0   9847.0    762.0  0.298  1.051    0.0     0.0
# 15025  140.3         709.0    179.0      0.0  0.173  0.443  354.0   184.0
# 969    140.3         709.0    179.0      0.0  0.173  0.443  354.0   184.0
# 23     117.7        2784.0  10566.0    696.0  0.295  0.930    0.0     0.0
# 4987   110.8        3081.0  10961.0    297.0  0.279  0.820    0.0     0.0
# 10047  110.5         677.0   1315.0     12.0  0.154  0.429  311.0   205.0
# 1595   106.9         759.0   1591.0      5.0  0.171  0.395  355.0   227.0
# 1556   106.5        2404.0   8352.0    548.0  0.267  0.908    0.0     0.0
# 4616   102.1         619.0    625.0      1.0  0.125  0.305  303.0   166.0
#
#         ERA  WHIP  Saves Draft Type State
# 291    0.00  0.00    0.0        4Yr    AZ
# 2014   0.00  0.00    0.0         HS    CA
# 15025  3.12  1.17    0.0         JC    TX
# 969    3.12  1.17    0.0        4Yr    TX
# 23     0.00  0.00    0.0         HS    FL
# 4987   0.00  0.00    0.0         HS    CA
# 10047  2.86  1.12    1.0        4Yr    CA
# 1595   3.16  1.14    0.0         HS    NV
# 1556   0.00  0.00    0.0        4Yr    OH
# 4616   3.29  1.17    2.0         HS    CA
